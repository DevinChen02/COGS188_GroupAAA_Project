# %% [markdown]
# # COGS 188 - Project Proposal

# %%
from IPython.display import Image

# %% [markdown]
# # Project Description:
# This project aims to design an AI agent that is capable of solving the Sudoku puzzle. Sudoku demands logical deduction skills, while Sudoku solvers exist, this project seeks to solve the puzzle using more advanced problem-solving strategies and algorithms, as well as machine learning techniques to improve the solving efficiency.
#
# ### Sudoku
# Sudoku (https://en.wikipedia.org/wiki/Sudoku) is a puzzle that combines the elements of Sudoku and Kakuro. The game is designed in the following way: the puzzle is 9 by 9 grid consisting of 81 cells. At the begining, there are a few cells filled with numbers and the rest of the cells are empty. A typical layout of the game is like the following:
#
# ![sudoku.png](./images/sudoku.png)
#
# The player's goal is to fill the grid with number 1 to 9 based on the following rule: each row, column, and nonet (a 3x3 grid of cells, also called a box) contains each number exactly once.
#
#
#
# ### Project overview
# 1. **Problem complexity:** \
# A 9 by 9 Sudoku puzzle has 9^81 number of different solutions, so using brute force to solve the puzzle is very inefficient. So a more time efficient approach is required.
#
# 2. **Model selection:** \
# Since different algorithms might differ in their performance in time and space, we plan to use different algorithms to solve the puzzle, and do a comparison of these algorithms. We will also use machine learning techniques to train an AI agent that could learn the best strategy by itself, and then compare the performance of the ML-agent with other agents we built. More detailed will be provided in the section [Proposed Solution](#-Proposed-Solution).
#
# 3. **Machine Learning techniques:**
# The project will explore Constraint Satisfaction techniques, reinforcement learning and Deep Learning approaches.
#
# 4. **Performance Evaluation:**
# The effectiveness of the AI agent will be measured by accuracy (this is more relevant to RL techniques, where it might/might not succesfully solve the puzzle) and efficiency. More details on section [Evaluation Metrics](#Evaluation-Metrics)
#
#
# ### Significance
# The project will enhance our understandings of various AI applications in games and puzzles. Our exploration of these algorithms and ML techniques are transferable to other domains like optimization problems, automated-decision making, and the field of computational complexity.

# %% [markdown]
# # Names
#
# Hopefully your team is at least this good. Obviously you should replace these with your names.
#
# - Zirui Lin
# - Yanxiong Chen
# - Jiawei Lyu

# %% [markdown]
# # Abstract
# This section should be short and clearly The project goal is to develop an AI agent that solves the classic Sudoku puzzles from a dataset with 9 million puzzles. Each puzzle in the dataset is represented by a row of 81 digits, capturing the Sudoku gird. We will use the data to train our RL and DL models, and to test our RL/DL models and the AI agents based on Constraint Satisfaction techniques. The AI's performance will be measured by its accuracy (percentage of puzzles correctly solved) and efficiency (time/number of steps to solution).

# %% [markdown]
# # Background
#
# The exploration of solutions to Sudoku, a popular logic game, has been a hot topic in computer science and mathematics research.Logically, Sudoku problems are essentially NP-complete problems <a name="thesis"></a>[<sup>[1]</sup>](#thesisnote)， This means that no single algorithm can solve all Sudoku instances most efficiently.Therefore, the choice of algorithms for solving Sudoku problems has become an important research direction, aiming at selecting the best solution from existing efficient algorithms, rather than redeveloping algorithms for each puzzle.<a name="thesis"></a>[<sup>[1]</sup>](#thesisnote).
#
# In recent years we can see numerous discussions of the sudoku problem appearing in the field of machine learning and programming, such as a new hybrid algorithm developed by a researcher that combines a variety of algorithms with all-different, a global constraint in constraint programming. The algorithm utilizes a forbidden search procedure to efficiently combine with all-different constraints, for efficient domain filtering of constraints that must be pairwise different <a name="soto"></a>[<sup>[2]</sup>](#sotonote).
#
# In this project, our group will also focus on using deep learning, reinforcement learning, or other unsupervised models (we haven't quite decided in detail yet) to try to explore the Sudoku problem in our own way.

# %% [markdown]
# # Problem Statement
# This problem can be formulated as a Constraint Satisfication Problem (reference Yanxiong Chen's HW3: will add an citation here): \
# **Set of variables**: \
# Let $X_{i,j}$ denotes the cell on the i-th row and j-th column of the 9 by 9 game board. Then there will be a set of 81 variables: $\{X_{1,1}, X_{1, 2}, ..., X_{2, 1}, ..., X_{9,9}\}$. \
# **Set of domains for each variable**: \
# Set of domains $D_{i,j} = \{1, 2, 3, 4, 5, 6, 7, 8, 9\}$. \
# **Set of constraints that specify allowable combinations of values:** \
# 1. Any row in the grid contains all of the number from 1 - 9:  for any row $i \in [1, 9]$, Alldiff($X_{i, 1}, X_{i, 2}, ..., X_{i, 9}$), and $X_{i,j} \in \{1, 2, 3, ..., 9\}$.
#
# 2. Any column in the grid contains all of the number from 1 - 9: for any column $j \in [1, 9]$, Alldiff($X_{1, j}, X_{2, j}, ..., X_{9, j}$), and $X_{i,j} \in \{1, 2, 3, ..., 9\}$.
#
# 3. Each 3 by 3 subgrid (a total of 9 of such subgrids) in the game board must contain all of the digits from 1 - 9: \ The following sets must contain all digits from 1 - 9 with no duplicates:
# $$
# \begin{Bmatrix}X_{1, 1}, X_{1, 2}, X_{1, 3} \\
# X_{2, 1}, X_{2, 2}, X_{2, 3} \\
# X_{3, 1}, X_{3, 2}, X_{3, 3} \end{Bmatrix},  ..., \\
# \begin{Bmatrix}X_{6, 7}, X_{6, 8}, X_{6, 9} \\
# X_{7, 7}, X_{7, 8}, X_{7, 9} \\
# X_{9, 7}, X_{9, 8}, X_{9, 9} \end{Bmatrix}
# $$

# %% [markdown]
# # Data
#
# ### Data Link: https://www.kaggle.com/datasets/rohanrao/sudoku/data
#
#
# ### Variable description
# The dataset contains two main variables:
# 1. **Puzzle**.
#    - **Description**: A Sudoku layout in string form containing 81 characters. Each character represents a grid on the sudoku board, and the '0' character indicates that the position is empty and needs to be filled.
#    - **Format**: 81 characters long string.
#
# 2. **Solution**
#    - **Description**: A sudoku completion solution in string form, also containing 81 characters, showing the number of fillers in each grid.
#    - **Format**: String of 81 characters.
#
# ### Number of observations
# - **Total**: The dataset contains a total of 9 million observations, i.e. 9 million Sudoku puzzles and their corresponding solutions.
#
# ## Observations Composition
# Each row represents a Sudoku puzzle and its corresponding solution. The numbers are arranged in order from left to right and top to bottom, using `0` to denote a blank cell in the puzzle.
#
# ## Key variables and their representations
# - **puzzle**: A string of 81 characters representing a 9x9 sudoku layout, where  `0` represents a blank cell.
# - **solution**: a string of 81 characters representing the completed Sudoku layout.
#
# ## Data processing requirements
# - **Conversion**: We need to convert the string format of each sudoku into a 9x9 matrix so that the model can process the sudoku layout more intuitively.
# - **Cleaning**: Given that the data is already of high quality and in a uniform format, there is basically no need for additional cleaning. However, due to the sheer size of our data, we may not use all 9 million pieces of data in our training, but rather some of them (e.g. half, depending on our model and hardware level).
# - **Special Handling**: Depending on the model, we may rotate and map the sudoku data to enhance the complexity of the training data.

# %% [markdown]
# # Proposed Solution
#
# The benchmark model will be to solve Sudoku entirely by brute force. Our solution will be a combination of trick and brute force solutions.
#
# First, each cell will belong to three parts: row, column, and subgrid, which will have candidates (1-9), and each part (cell, row, column, subgrid) will have three sets of numbers: candidate, filled, and determined, and row, column, and subgrid will have a list of cells that belong to it. Then they will update candidate based on the information that is already there, with a boolean, changed, that indicates whether or not an update has been made.
#
# For this section, we have a total of three functions:
# Update cells: update the number of candidates.
# Update row/column/subgrid: check the cells it owns, update its candidate according to the information (filled, determined) it already has, and at the same time, update the information of all the cells it owns (using the update cells method).
# After performing all the operations, we can get the result similar to the following figure:

# %%
Image("img/sudoku1.png")

# %% [markdown]
# After explaining the method of updating information in Sudoku, we can start discussing the solution:
#
# The sudoku solution will be divided into two parts: the trick solution and the brute force solution. Let's start with the trick solution:
#
# 1) Fill only candidate: This is a method for cells where we move a cell from the candidate set to the filled set if it has only one remaining candidate, and we update the row, column, and subgrid to which it belongs.
#
# Def Fill only candidate():
#
# 	Updated = True
# 	Changed = False
# 	While Updated:
# 		Change made = False
# 		Updated = False
# 		For all cells:
# 			If meet requirement:
# 				Execute update
# 				Updated = True
# 				Changed = True
# 	Return changed
#
#
# We'll get a result similar to the one below, and we'll also see that there are other cells could be solved by this technique appearing (e.g., the cell in the eighth column of the third row), so the fill only candidate will be executed repeatedly until no new changes happen.

# %%
Image("img/sudoku2.png")

# %% [markdown]
# 2) hidden single
#
# See below, we can see that for the first row, the seventh column, and the third subgrid, there is only one cell that can be filled with the number 2. Therefore, this cell must be filled with the number 2, and at the same time, the rows, columns, and subgrids to which it belongs are updated. similarly, this fucntion is repeated until there are no more qualified cells.
#
# Def hidden single():
#
# 	Updated = True
# 	Changed = False
# 	While updated:
# 		Updated = False
#
#         For all rows:
#           For all candidates:
#             If only one cell can fill in this candidate:
#               Execute update
#               Updated = True
#               Changed = True
#
#         For all columns:
#           For all candidates:
#             If only one cell can fill in this candidate:
#               Execute update
#               Updated = True
#               Changed = True
#
#         For all subgrids:
#           For all candidates:
#             If only one cell can fill in this candidate:
#               Execute update
#               Updated = True
#               Changed = True
# 	Return Changed

# %%
Image("img/sudoku4.png")

# %% [markdown]
# At this point, we can solve all the easy level sudoku, but for the more difficult sudoku, we still need other skills.
#
# 3) Determined candidate for subgrid: see the picture below, we can see that in the third subgrid, there are only two cells that can be filled with 4, and at the same time, these two cells belong to the same row. The two cells belong to the same subgrid. Therefore, we can determine that the other cells in the third row cannot be filled with 4. (The same applies to the columns.)
#
# We will:
# - for cells, put 4 from the candidate set into the determined set
# - For rows/columns, put 4 from the candidate set into the determined set and update the cells that belong to it.

# %%
Image("img/sudoku5.png")

# %% [markdown]
# Def Determined candidate for subgrid():
#
# 	Updated = True
# 	Changed = False
# 	While Updated:
# 		Updated = False
# 		For all subgrids:
# 			For all candidates:
# 				If meet requirement:
# 					Execute update
# 					Updated = True
# 					Changed = True
# 	Return chagned

# %% [markdown]
# Similarly, we will have Determined candidate for row and Determined candidate for column, see the figure below, we can see that there are only two positions in the first row that can be filled with 1, and at the same time, these two cells belong to the same subgrid, so we can confirm that the other cells in this subgrid can't be filled with 1. Therefore, we can confirm that the other cells in this subgrid cannot be filled with 1.
#
# We will:
# - for the cells, put 1 from the candidate set into the determined set
# - For the subgrid, put 1 from the candidate set into the determined set and update the cells that belong to it.

# %%
Image("img/sudoku6.png")

# %% [markdown]
# Def Determined candidate for row/column():
#
# 	Updated = True
# 	Changed = False
# 	While Updated:
# 		Updated = False
# 		For all rows/columns:
# 			For all candidates:
# 				If meet requirement:
# 					Execute update
# 					Updated = True
# 					Changed = True
# 	Return changed

# %% [markdown]
# The rest of the cells can already be solved by the existing methods (fill only candidate, hidden single).
# The sudoku can be solved by repeating all the fucntions.
#
#     Change made = True
#     While Change made:
# 	Change made = False
# 	If Update row/column/subgrid():
# 		Change made = True
# 	If Fill only candidate():
# 		Change made = True
# 	If hidden single():
# 		Change made = True
# 	If Determined candidate for subgrid():
# 		Change made = True
# 	If Determined candidate for row/column():
# 		Change made = True
#
# With all the tricks available, we can solve some of the median level sudoku, besides that, there are a lot of tricks that we haven't mentioned. For the rest, we will use a brute force solution. The solution is similar to a lab 3 coloring game.

# %% [markdown]
# # Contrasting Models 1: CNN
#
# We believe that CNNs should not perform well for sudoku problems because CNNs' specialty is understanding relationships between complex data (like pixels in an image), whereas for sudoku the relationships between the data are too explicit, and CNNs may spend unnecessary time on confirming these well-recognized, relationships between numbers. However, we believe that it can still solve the problem, because the essence of Sudoku is the relationship between numbers in a square grid.
#
# ## 1.Model Design
#
# ### Build the CNN architecture
# - **Input Layer:** Accepts inputs of shape 9x9x1.
# - **Convolutional Layer:** Activation function uses ReLU.
# - **Pooling Layer:** Selected based on model specific performance.
# - **Fully Connected Layer:** A fully connected layer that performs the final data processing.
# - **Output Layer:** The expected output is set to 81 softmax outputs (9x9).
#
# ### Compile the model
# - **Loss function:** `categorical_crossentropy` or `mean_squared_error`.
# - **Optimizer:** Adam is expected to be used.
# - **Evaluation metrics:** Accuracy, defined by our own cost (see below).
#
# ## 2. Model Training
#
# ### Training process
# - **Batch Size:** Expected to be 64.
# - **Epochs:** Flexible and variable, expected to be debugged during training.
# - **Early Stopping:** Again flexible and variable.
#
# ## 3. Performance Evaluation
#
# ### Evaluate the model using test sets
# - **Evaluate:** Perform model evaluation on the test set and record metrics such as accuracy and loss.
#
# ## 4. Model Optimization and Tuning
#
# ### Tuning and optimization
# - **Hyper-parameter tuning:** Tweak the learning rate, batch size, number of layers, etc., in short tweak everything we can.
# - **Cross-validation:** Ensure model performance consistency across different data subsets.

# %% [markdown]
# # Contrasting Models 2: Backtracking Search Algorithm
#
# We think this will be the best performing model, and we plan to accomplish it in the following general steps
#
# ## 1. Description of the Backtracking Algorithm
#
# For Sudoku, the algorithm starts at the first space in the grid, tries to fill in a suitable number between 1 and 9, and then recursively continues to the next space. If, at any point, the number filled in violates the rules of Sudoku, the algorithm undoes (backtracks) the previous step and tries another number.
#
# ## 2. Algorithm implementation steps
#
# ### Step 1: Selecting spaces
# - Traverse the Sudoku grid from left to right, top to bottom.
# - Select the first blank square (the one without numbers).
#
# ### Step 2: Try to fill in the numbers
# - For each blank, try to fill the numbers 1 through 9.
# - For each number, check to see if it satisfies the constraints in the rows, columns and 3x3 grid of the Sudoku.
#   - If it is satisfied, recursively move on to the next space.
#   - If not, try the next number.
#
# ### Step 3: Checking for grid completion
# - If all spaces are successfully filled, the algorithm ends and the sudoku is solved.
# - If a space cannot be filled with any number from 1 to 9, go back to the previous space and change its number.
#
# ## 4. Some possible optimizations for processing
# - **Use preprocessing techniques**: fill in some digits before the algorithm starts, using the basic strategy of sudoku (such as the one described above).
# - **Heuristic selection**: prioritize filling the grid with fewer candidate numbers.
#
# ## 5. End condition
# - When all spaces are filled correctly, output the solution.
# - If backtracking to the first grid and trying all the digits has no solution, report that the sudoku has no solution.

# %% [markdown]
# # Evaluation Metrics
#
# In this project, the evaluation metric we are primarily interested in is the number of steps used to solve Sudoku.
#
# 1. **Number of steps defined**:
#    - **Fill in the numbers**: each time a number is filled in or counted as a step.
#    - **Using a fixed solving technique**: using a fixed solving technique once is counted as one step. Fixed solving techniques usually include logical reasoning methods commonly used in Sudoku, such as Unique Candidate Number, Hidden Candidate Number, and so on. These methods are manually edited by us and made available to the computer to speed up their learning (this is what we envisioned). Of course, depending on our model or when we try to solve problems with deep learning/reinforcement learning we do not provide these techniques.
#
# 2. **Calculation of the number of steps**:
#    - **Total number of steps**: the sum of the number of times all operations to update a cell are performed from the start to the completion of the solution.
#
# 3. **Comparison of efficiency**:
#    - We assume that solving Sudoku puzzles using fewer steps indicates higher efficiency and better algorithmic performance. Therefore, comparing the number of steps for different solutions will be key to evaluating the effectiveness of these models. Note, however, that if a model does not succeed in solving a Sudoku, then its efficiency will go to zero. However, after that our checking function will not be wrong in practice this will not happen and the model will always give a correct solution in the end.
#
# 4. **Mathematical expression**:
#    - Let $S$ be a solution and $N(S)$ denote the number of steps required to complete Sudoku. We will use the following formula to evaluate and compare the various algorithms:
#
# $$
# E(S) =
# \begin{cases}
# N(S) & \text{if Answer is correct} \\\\
# 0 & \text{if Answer is incorrect}
# \end{cases}
# $$
#
#
#    where $$ E(S)$$ is the efficiency score and $$ N(S)$$ is the total number of steps required to complete the solution $$ S$$.
#
# 5. **Practical Application Example**:
#    - Suppose we have Algorithm A and Algorithm B. On the same Sudoku puzzle, Algorithm A uses 45 steps to complete the solution, while Algorithm B uses 65 steps and both of them give the correct answer in the end. According to our evaluation metrics, Algorithm A (45 steps) is more efficient than Algorithm B (65 steps).

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# This project is designed and implemented to adhere to strict ethical standards of data science to ensure that the data is processed legally and ethically, while protecting user privacy (which we won't actually cover) and data security.
#
# ### Data collection
# - **Informed Consent**: we do not collect data directly from users and therefore do not require their informed consent. And because this project uses open source data, we hold a license to use that data.
# - **Collection Bias**: The Sudoku dataset we use does not introduce gender, racial, or other social biases; it is purely and simply a math game.
# - **Limitation of Personally Identifiable Information (PII) Exposure**: This project does not involve any personally identifiable information and is based entirely on impersonal data.
#
# ### Data Storage
# - **DATA SECURITY**: All data used is stored on secure servers (colabs), necessary security measures are taken, and we limit sharing and reading/editing permissions on project links to ensure that the data is not subject to unauthorized access.
# - **Data Retention Plan**: All data is deleted from the server immediately after the completion of the project without any form of persistent storage.
#
# ### Analyze
# - **Honest Representation**: All data analysis and algorithm outputs will be presented in the most honest and transparent manner possible, and all visualizations will be based on rigorous mathematical conclusions. All conclusions and data representations we make in this project are accurate and have not been distorted or deliberately manipulated.
#
# ### Modeling
# - **Cross-group fairness**: The model will be tested on different types of Sudoku puzzles to ensure that the algorithm solves all types of Sudoku with equal efficiency.
# - **Explainability**: We will ensure the transparency and explainability of the model's decision-making process and provide detailed written text and diagrams of our model's principles so that readers can understand how the model works and the logic of the solution.
#
# ### Deployment
# - **Unintended Use**: We will monitor all usage records of our model to ensure that it is not used by others without our authorization for purposes other than completing the project (e.g., at its simplest, academic plagiarism) to avoid violations.

# %% [markdown]
# # Team Expectations

# %% [markdown]
# ## Team expectations
#
# * **The way the team communicates and interacts**:
#   * We will communicate regularly through online meetings and daily WeChat group chats.
#   * * All meeting minutes and important decisions will be shared and documented by Zirui Lin.
#
# * **Conflict and Difficulty Management**:
#   * When faced with conflicts and difficulties, we will use open discussion to ensure that each team member's opinion is fully heard. If a unified answer is not forthcoming... We will continue the discussion to get a unified answer (geez there are only three of us, we can't still vote on it lol)
#
#
# * **Decision Making and Goal/Schedule Setting**:
#   * Decision making will be based on team discussions and each member's understanding of the direction of the project.
#   * Goals and schedule will be set during team meetings, as of right now we are planning to finish writing the Project proposal on May 3rd.
#
# * **Expected workload for each member**:
#   * Zirui Lin: Responsible for organizing and editing data, writing reports and visualizing model results
#   * Jiawei Lyu: responsible for model training
#   * Yanxiong chen: responsible for the evaluation of the model, analysis of the model results and writing of the text report together with Zirui Lin.
#   *PS: It should be noted that this is only a very generalized plan, in general the three of us will help each other, and each of us will be involved in all aspects to complete our tasks.
#
# * **Deadline Handling**:
#   * The sooner the better, we plan to complete the task as early as possible to get early feedback.
#   * The first deadline is May 3
#
# * **Quality Control and Review**:
#   * We will use colab for collaborative work and check the work product of other members as we work to ensure quality.

# %% [markdown]
# # Project Timeline Proposal

# %% [markdown]
# Here's where we are as of now, note that we don't meet at 5:00 every time, we just summarize and update the status of our work at 5:00pm every time for convenience.
#
# | Date of meeting | Time of meeting | Matters to be completed before the meeting | Content of discussion at the meeting |
# | -----------| ----------| ------------------------------------------------| -----------------------------------------------------|
# | 4/29 | 5 PM | Brainstorm, identify potential topics and data sources | Decide on final project topics; discuss and assign initial research responsibilities |
# | 4/30 | 5 PM | Brainstorm, change project topics; determine databases to be used | Determine and discuss feasibility of new topics and associated research methods; reassign duties | 4/29 | 5 PM | Brainstorm, identify potential topics and data sources; discuss and assign initial research duties
# | 5/1 | 5 PM | Work through the details of the project topic and division of labor | In-depth discussion of the process of conducting the project and the specific responsibilities of each member of the team | 5/2 | 5 PM | Work through the details of the project topic and division of labor
# | 5/2 | 5 PM | Determine final project topic and division of labor | Confirm division of labor is clear, discuss steps for project implementation and upcoming tasks | 5/3 | 5 PM | Discuss the project's implementation process and upcoming tasks.
# | 5/3 | 5 PM | Begin their respective tasks | Review and critique the first draft of the project proposal to make sure that all necessary parts have been completed | 5/4 | 5 PM | Review the first draft of the project proposal to make sure that all necessary parts have been completed
# | 5/4 | 5 PM | Complete the first draft of the project proposal | Submit the final project proposal and discuss specific next steps for research and development |
#
# Here's what we plan to do after that
#
# | Date of meeting | Time of meeting | Matters to be completed before the meeting | Content of discussion at the meeting |
# |-----------|----------|--------------------------------------------------|------------------------------------------------------- ----|
# | 4/29 | 5 PM | Brainstorm, identify potential topics and data sources | Decide on final project topics; discuss and assign initial research responsibilities |
# | 4/30 | 5 PM | Brainstorm, change project topics; determine databases to be used | Determine and discuss feasibility of new topics and associated research methodology; reassign duties |
# | 5/1 | 5 PM | Work through the details of the project topic and division of labor | In-depth discussion of the process of conducting the project and the specific responsibilities of each member of the team | 5/2 | 5 PM | Work through the details of the project topic and division of labor
# | 5/2 | 5 PM | Determine final project topic and division of labor | Confirm division of labor is clear, discuss project steps and upcoming tasks | 5/3 | 5 PM | Discuss the project's implementation process.
# | 5/3 | 5 PM | Begin their respective tasks | Review and critique the first draft of the project proposal to make sure that all necessary sections have been completed | 5/4 | 5 PM | Review the first draft of the project proposal to make sure that all necessary sections have been completed
# | 5/4 | 5 PM | Finish the first draft of the project proposal | Submit the final project proposal and discuss the types of models to be deployed |
# | 5/11 | 5 PM | Formalize work, discuss types of models to deploy | Finish processing data, discuss and write prototype training models |
# | 5/14 | 5 PM | Complete data processing and model prototyping | Begin training models and evaluating preliminary results |
# | 5/20 | 5 PM | Adjust model based on preliminary results and continue training | Complete training of second comparison model and discuss results of both models |
# | 5/25 | 5 PM | Finish training all models and collect data | Collect and evaluate results from all models, begin writing lab reports and visualizing results |
# | 5/30 | 5 PM | Write the experiment report and visualize the results | Finish the final version of the project report, prepare it for submission, and discuss the project summary and possibilities for future work |

# %% [markdown]
# # Footnotes
# 1. <a name="thesisnote">Rajwardhan Kumar, "Algorithm Selection using Machine Learning for Sudoku Puzzles," Master's thesis, 2021. computer science, mathematics.</a>
#
# 2. <a name="sotonote">Ricardo Soto et al., "A Hybrid alldifferent-Tabu Search Algorithm for Solving Sudoku Puzzles," publish at "Computational Intelligence…",May 20, 2015 . Computer Science, Math.</a>
